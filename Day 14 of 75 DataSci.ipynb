# %% [markdown]
# # Problem
# Predict the price of a house based on its size.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Sample data (Size in square feet, Price in dollars)
sizes = np.array([1500, 2000, 2500, 3000, 3500]).reshape(-1, 1)
prices = np.array([300000, 400000, 500000, 600000, 700000])

# %%
model = LinearRegression()
model.fit(sizes, prices)
# Out:
# LinearRegression()

# %%
# Predict the price for a house of size 2800 sq ft
#n=int(input("Enter the size :"))
size_to_predict = np.array([[2800]])
predicted_price = model.predict(size_to_predict)
print(predicted_price)
# Out:
# [560000.]

# %%
print(f"Predicted price for a 2800 sq ft house: ${predicted_price[0]:,.2f}")
# Out:
# Predicted price for a 2800 sq ft house: $560,000.00

# %%
# Plotting the data and the regression line
plt.scatter(sizes, prices, color='black', label='Data Points')
plt.plot(sizes, model.predict(sizes), color='blue', label='Regression Line')
plt.xlabel('Size (sq ft)')
plt.ylabel('Price ($)')
plt.title('Linear Regression - House Prices')
plt.legend()
plt.show()
