# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample dataset
X = np.array([1, 2, 3, 4, 5])  # Features
y = np.array([1.2, 1.9, 3.0, 4.1, 5.1])  # Target values

# Adding a bias term (intercept)
X_b = np.c_[np.ones((X.shape[0], 1)), X]  # Add a column of ones

# Calculate the parameters using the Normal Equation
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# Predicted values
y_pred = X_b.dot(theta_best)

# Parameters
print("Intercept:", theta_best[0])
print("Slope:", theta_best[1])

# Plotting the results
plt.scatter(X, y, color="blue", label="Actual data")
plt.plot(X, y_pred, color="red", label="Regression line")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
import numpy as np
import matplotlib.pyplot as plt

# Sample dataset
X = np.array([1, 2, 3, 4, 5])  # Features
y = np.array([1.2, 1.9, 3.0, 4.1, 5.1])  # Target values

# Adding a bias term (intercept)
X_b = np.c_[np.ones((X.shape[0], 1)), X]  # Add a column of ones

# Calculate the parameters using the Normal Equation
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# Predicted values
y_pred = X_b.dot(theta_best)

# Parameters
print("Intercept:", theta_best[0])
print("Slope:", theta_best[1])

# Plotting the results
plt.scatter(X, y, color="blue", label="Actual data")
plt.plot(X, y_pred, color="red", label="Regression line")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
# Out:
# Intercept: 0.06000000000000262
# Slope: 1.0000000000000002
# Intercept: 0.06000000000000262
# Slope: 1.0000000000000002
